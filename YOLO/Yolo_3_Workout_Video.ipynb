# %%
import cv2
import ultralytics
from ultralytics import solutions
from ultralytics.utils.downloads import safe_download


ultralytics.checks()
# Out:
# Ultralytics 8.3.192  Python-3.12.10 torch-2.8.0+cpu CPU (11th Gen Intel Core(TM) i5-11320H 3.20GHz)
# Setup complete  (8 CPUs, 15.7 GB RAM, 283.4/476.2 GB disk)

# %%
exercises_list = ["Legextension", "Legpress", "Squats", "Pushups"]

for exercise in exercises_list:
    safe_download(f"https://github.com/ultralytics/assets/releases/download/v0.0.0/{exercise}.demo.video.mp4")
# Out:
# Downloading https://ultralytics.com/assets/Legextension.demo.video.mp4 to 'Legextension.demo.video.mp4': 100% ━━━━━━━━━━━━ 5.9/5.9MB 11.4MB/s 0.5s0.1s2s
# Downloading https://ultralytics.com/assets/Legpress.demo.video.mp4 to 'Legpress.demo.video.mp4': 100% ━━━━━━━━━━━━ 7.9/7.9MB 4.7MB/s 1.7s<0.0ss6s
# Downloading https://ultralytics.com/assets/Squats.demo.video.mp4 to 'Squats.demo.video.mp4': 100% ━━━━━━━━━━━━ 3.4/3.4MB 13.2MB/s 0.3s0.1s
# Downloading https://ultralytics.com/assets/Pushups.demo.video.mp4 to 'Pushups.demo.video.mp4': 100% ━━━━━━━━━━━━ 4.0/4.0MB 750.9KB/s 5.4s1s0s.4s

# %%
cap = cv2.VideoCapture(r"C:\Users\divya\Desktop\DataScienceProjects\nareshit_datascience\YOLO\Pushups.demo.video.mp4")
assert cap.isOpened(), "Error reading video file"

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("Pushups.demo.video.output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init AIGym
gym = solutions.AIGym(
    show=True,  # Display the frame
    kpts=[5, 7, 9],  # keypoints index of person for monitoring specific exercise, by default it's for pushup
    model="yolo11n-pose.pt",  # Path to the YOLO11 pose estimation model file
    line_width=4,  # Adjust the line width for bounding boxes and text display
    verbose=False,
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = gym(im0)  # monitor workouts on each frame
    video_writer.write(results.plot_im)  # write the output frame in file.

video_writer.release()
# Out:
# requirements: Ultralytics requirement ['shapely>=2.0.0'] not found, attempting AutoUpdate...
# Defaulting to user installation because normal site-packages is not writeable
# Collecting shapely>=2.0.0
#   Downloading shapely-2.1.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\divya\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from shapely>=2.0.0) (2.1.3)
# Downloading shapely-2.1.1-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------------ --- 1.6/1.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 13.1 MB/s eta 0:00:00
# Installing collected packages: shapely
# Successfully installed shapely-2.1.1
#
# requirements: AutoUpdate success  7.1s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11n-pose.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [5, 7, 9], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 4, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': False, 'data': 'images'}
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-pose.pt to 'yolo11n-pose.pt': 100% ━━━━━━━━━━━━ 6.0/6.0MB 11.9MB/s 0.5s0.1s
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lap>=0.5.12
#   Downloading lap-0.5.12-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\divya\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from lap>=0.5.12) (2.1.3)
# Downloading lap-0.5.12-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 12.9 MB/s eta 0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.12
#
# requirements: AutoUpdate success  3.5s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      21         print("Video frame is empty or video processing has been successfully completed.")
#      22         break
# ---> 23     results = gym(im0)  # monitor workouts on each frame
#      24     video_writer.write(results.plot_im)  # write the output frame in file.
#      26 video_writer.release()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\solutions\solutions.py:248, in BaseSolution.__call__(self, *args, **kwargs)
#     246 """Allow instances to be called like a function with flexible arguments."""
#     247 with self.profilers[1]:
# --> 248     result = self.process(*args, **kwargs)  # Call the subclass-specific process method
#     249 track_or_predict = "predict" if type(self).__name__ == "ObjectCropper" else "track"
#     250 track_or_predict_speed = self.profilers[0].dt * 1e3
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\solutions\ai_gym.py:77, in AIGym.process(self, im0)
#      52 """
#      53 Monitor workouts using Ultralytics YOLO Pose Model.
#      54
#    (...)     73     >>> processed_image = results.plot_im
#      74 """
#      75 annotator = SolutionAnnotator(im0, line_width=self.line_width)  # Initialize annotator
# ---> 77 self.extract_tracks(im0)  # Extract tracks (bounding boxes, classes, and masks)
#      79 if len(self.boxes):
#      80     kpt_data = self.tracks.keypoints.data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\solutions\solutions.py:172, in BaseSolution.extract_tracks(self, im0)
#     160 """
#     161 Apply object tracking and extract tracks from an input image or frame.
#     162
#    (...)    169     >>> solution.extract_tracks(frame)
#     170 """
#     171 with self.profilers[0]:
# --> 172     self.tracks = self.model.track(
#     173         source=im0, persist=True, classes=self.classes, verbose=False, **self.track_add_args
#     174     )[0]
#     175 is_obb = self.tracks.obb is not None
#     176 self.track_data = self.tracks.obb if is_obb else self.tracks.boxes  # Extract tracks for OBB or object detection
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\model.py:601, in Model.track(self, source, stream, persist, **kwargs)
#     599 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     600 kwargs["mode"] = "track"
# --> 601 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\model.py:557, in Model.predict(self, source, stream, predictor, **kwargs)
#     555 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     556     self.predictor.set_prompts(prompts)
# --> 557 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\predictor.py:229, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     227     return self.stream_inference(source, model, *args, **kwargs)
#     228 else:
# --> 229     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\utils\_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\predictor.py:332, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     330 # Inference
#     331 with profilers[1]:
# --> 332     preds = self.inference(im, *args, **kwargs)
#     333     if self.args.embed:
#     334         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\predictor.py:184, in BasePredictor.inference(self, im, *args, **kwargs)
#     178 """Run inference on a given image using the specified model and arguments."""
#     179 visualize = (
#     180     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     181     if self.args.visualize and (not self.source_type.tensor)
#     182     else False
#     183 )
# --> 184 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\autobackend.py:637, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     635 # PyTorch
#     636 if self.pt or self.nn_module:
# --> 637     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     639 # TorchScript
#     640 elif self.jit:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\modules\head.py:386, in Pose.forward(self, x)
#     384 bs = x[0].shape[0]  # batch size
#     385 kpt = torch.cat([self.cv4[i](x[i]).view(bs, self.nk, -1) for i in range(self.nl)], -1)  # (bs, 17*3, h*w)
# --> 386 x = Detect.forward(self, x)
#     387 if self.training:
#     388     return x, kpt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\modules\head.py:122, in Detect.forward(self, x)
#     119     return self.forward_end2end(x)
#     121 for i in range(self.nl):
# --> 122     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#     123 if self.training:  # Training path
#     124     return x
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\modules\conv.py:93, in Conv.forward_fuse(self, x)
#      83 def forward_fuse(self, x):
#      84     """
#      85     Apply convolution and activation without batch normalization.
#      86
#    (...)     91         (torch.Tensor): Output tensor.
#      92     """
# ---> 93     return self.act(self.conv(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\activation.py:434, in SiLU.forward(self, input)
#     433 def forward(self, input: Tensor) -> Tensor:
# --> 434     return F.silu(input, inplace=self.inplace)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\functional.py:2374, in silu(input, inplace)
#    2372     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2373 if inplace:
# -> 2374     return torch._C._nn.silu_(input)
#    2375 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:

# %%
cap = cv2.VideoCapture(r"C:\Users\divya\Desktop\DataScienceProjects\nareshit_datascience\YOLO\Squats.demo.video.mp4")
assert cap.isOpened(), "Error reading video file"

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("Squats.demo.video.output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init AIGym
gym = solutions.AIGym(
    show=True,  # Display the frame
    kpts=[5, 11, 13],  # keypoints index of person for monitoring specific exercise, by default it's for pushup
    model="yolo11m-pose.pt",  # Path to the YOLO11 pose estimation model file
    line_width=4,  # Adjust the line width for bounding boxes and text display
    verbose=False,
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = gym(im0)  # monitor workouts on each frame
    video_writer.write
    (results.plot_im)  # write the output frame in file.

video_writer.release()
# Out:
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11m-pose.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [5, 11, 13], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 4, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': False, 'data': 'images'}
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m-pose.pt to 'yolo11m-pose.pt': 100% ━━━━━━━━━━━━ 40.5/40.5MB 15.1MB/s 2.7s.3ss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 23
#      21     print("Video frame is empty or video processing has been successfully completed.")
#      22     break
# ---> 23 results = gym(im0)  # monitor workouts on each frame
#      24 video_writer.write
#      25 (results.plot_im)  # write the output frame in file.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\solutions\solutions.py:248, in BaseSolution.__call__(self, *args, **kwargs)
#     246 """Allow instances to be called like a function with flexible arguments."""
#     247 with self.profilers[1]:
# --> 248     result = self.process(*args, **kwargs)  # Call the subclass-specific process method
#     249 track_or_predict = "predict" if type(self).__name__ == "ObjectCropper" else "track"
#     250 track_or_predict_speed = self.profilers[0].dt * 1e3
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\solutions\ai_gym.py:77, in AIGym.process(self, im0)
#      52 """
#      53 Monitor workouts using Ultralytics YOLO Pose Model.
#      54
#    (...)     73     >>> processed_image = results.plot_im
#      74 """
#      75 annotator = SolutionAnnotator(im0, line_width=self.line_width)  # Initialize annotator
# ---> 77 self.extract_tracks(im0)  # Extract tracks (bounding boxes, classes, and masks)
#      79 if len(self.boxes):
#      80     kpt_data = self.tracks.keypoints.data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\solutions\solutions.py:172, in BaseSolution.extract_tracks(self, im0)
#     160 """
#     161 Apply object tracking and extract tracks from an input image or frame.
#     162
#    (...)    169     >>> solution.extract_tracks(frame)
#     170 """
#     171 with self.profilers[0]:
# --> 172     self.tracks = self.model.track(
#     173         source=im0, persist=True, classes=self.classes, verbose=False, **self.track_add_args
#     174     )[0]
#     175 is_obb = self.tracks.obb is not None
#     176 self.track_data = self.tracks.obb if is_obb else self.tracks.boxes  # Extract tracks for OBB or object detection
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\model.py:601, in Model.track(self, source, stream, persist, **kwargs)
#     599 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     600 kwargs["mode"] = "track"
# --> 601 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\model.py:557, in Model.predict(self, source, stream, predictor, **kwargs)
#     555 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     556     self.predictor.set_prompts(prompts)
# --> 557 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\predictor.py:229, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     227     return self.stream_inference(source, model, *args, **kwargs)
#     228 else:
# --> 229     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\utils\_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\predictor.py:332, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     330 # Inference
#     331 with profilers[1]:
# --> 332     preds = self.inference(im, *args, **kwargs)
#     333     if self.args.embed:
#     334         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\engine\predictor.py:184, in BasePredictor.inference(self, im, *args, **kwargs)
#     178 """Run inference on a given image using the specified model and arguments."""
#     179 visualize = (
#     180     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     181     if self.args.visualize and (not self.source_type.tensor)
#     182     else False
#     183 )
# --> 184 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\autobackend.py:637, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     635 # PyTorch
#     636 if self.pt or self.nn_module:
# --> 637     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     639 # TorchScript
#     640 elif self.jit:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\modules\block.py:318, in C2f.forward(self, x)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\modules\block.py:318, in <genexpr>(.0)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\modules\block.py:353, in C3.forward(self, x)
#     351 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     352     """Forward pass through the CSP bottleneck with 3 convolutions."""
# --> 353     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ultralytics\nn\modules\conv.py:93, in Conv.forward_fuse(self, x)
#      83 def forward_fuse(self, x):
#      84     """
#      85     Apply convolution and activation without batch normalization.
#      86
#    (...)     91         (torch.Tensor): Output tensor.
#      92     """
# ---> 93     return self.act(self.conv(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:

# %%
import numpy as np
x=np.array([np.nan,0.0,1.0,np.nan,2.0])
mask=~np.isnan(x) & (x>0)
y=x[mask]

print(y.sum(),mask.sum())
# Out:
# 3.0 2
